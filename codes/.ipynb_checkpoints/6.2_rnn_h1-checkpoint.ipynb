# %% [markdown]
# # <font color=green>Recurrent Neural Networks for H1 Time frame</font>

# %% [markdown]
# # <font color=green>Import Libraries</font>

# %%
from datetime import datetime
import numpy as np
import pandas as pd
pd.set_option("display.max.columns", None)

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, 
    recall_score,
    precision_score,
    classification_report,
    confusion_matrix
)

from keras.models import Sequential
from keras import regularizers
from keras.callbacks import EarlyStopping
from keras.layers import Dense, Dropout, GRU
from keras.optimizers import Adam
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.utils import to_categorical

# %% [markdown]
# # <font color=green>H1 Timeframe</font>

# %%
# read in H1 timeframe price data
df_h1_feature = pd.read_csv('../data/df_h1_feature.csv', index_col=0)
df_h1_feature.index = pd.to_datetime(df_h1_feature.index)
df_h1_feature = df_h1_feature.dropna()
df_h1_feature.head()
# Out:
#                        open    high     low   close  results  hr_of_day  \
# 2003-01-07 12:00:00  1.0424  1.0428  1.0408  1.0410        2         12
# 2003-01-07 13:00:00  1.0409  1.0425  1.0408  1.0413        2         13
# 2003-01-07 14:00:00  1.0414  1.0419  1.0403  1.0414        2         14
# 2003-01-07 15:00:00  1.0415  1.0422  1.0413  1.0418        2         15
# 2003-01-07 16:00:00  1.0419  1.0420  1.0413  1.0413        2         16
#
#                      day_of_wk  shift_01  close_shift_01_dist  shift_02  \
# 2003-01-07 12:00:00          1    1.0423                 -1.3    1.0436
# 2003-01-07 13:00:00          1    1.0410                  0.3    1.0423
# 2003-01-07 14:00:00          1    1.0413                  0.1    1.0410
# 2003-01-07 15:00:00          1    1.0414                  0.4    1.0413
# 2003-01-07 16:00:00          1    1.0418                 -0.5    1.0414
#
#                      close_shift_02_dist  shift_03  close_shift_03_dist  \
# 2003-01-07 12:00:00                 -2.6    1.0435                 -2.5
# 2003-01-07 13:00:00                 -1.0    1.0436                 -2.3
# 2003-01-07 14:00:00                  0.4    1.0423                 -0.9
# 2003-01-07 15:00:00                  0.5    1.0410                  0.8
# 2003-01-07 16:00:00                 -0.1    1.0413                  0.0
#
#                      shift_05  close_shift_05_dist  shift_08  \
# 2003-01-07 12:00:00    1.0429                 -1.9    1.0410
# 2003-01-07 13:00:00    1.0416                 -0.3    1.0412
# 2003-01-07 14:00:00    1.0435                 -2.1    1.0409
# 2003-01-07 15:00:00    1.0436                 -1.8    1.0429
# 2003-01-07 16:00:00    1.0423                 -1.0    1.0416
#
#                      close_shift_08_dist  shift_13  close_shift_13_dist  \
# 2003-01-07 12:00:00                  0.0    1.0440                 -3.0
# 2003-01-07 13:00:00                  0.1    1.0439                 -2.6
# 2003-01-07 14:00:00                  0.5    1.0452                 -3.8
# 2003-01-07 15:00:00                 -1.1    1.0436                 -1.8
# 2003-01-07 16:00:00                 -0.3    1.0411                  0.2
#
#                      shift_21  close_shift_21_dist  shift_34  \
# 2003-01-07 12:00:00    1.0472                 -6.2    1.0434
# 2003-01-07 13:00:00    1.0465                 -5.2    1.0459
# 2003-01-07 14:00:00    1.0448                 -3.4    1.0469
# 2003-01-07 15:00:00    1.0447                 -2.9    1.0478
# 2003-01-07 16:00:00    1.0445                 -3.2    1.0487
#
#                      close_shift_34_dist  shift_55  close_shift_55_dist  \
# 2003-01-07 13:00:00         -1.651408         -5.419061         -8.589406
# 2003-01-07 14:00:00         -0.596007         -7.106124         -5.827630
# 2003-01-07 15:00:00         -0.734839         -6.290220         -3.533009
# 2003-01-07 16:00:00         -1.643174         -6.185835         -2.440774
#
#                      rsi_14_sma_21m03  rsi_14_sma_21m02
# 2003-01-07 12:00:00         -7.663242         -3.268239
# 2003-01-07 13:00:00         -3.307687         -1.262833
# 2003-01-07 14:00:00         -1.794582         -2.855024
# 2003-01-07 15:00:00         -3.923864         -4.935997
# 2003-01-07 16:00:00         -3.923524         -4.615789

# %%
df_h1_feature.shape
# Out:
# (105518, 186)

# %%
df_h1_feature.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 105518 entries, 2003-01-07 12:00:00 to 2019-12-30 16:00:00
# Columns: 186 entries, open to rsi_14_sma_21m02
# dtypes: float64(183), int64(3)
# memory usage: 150.5 MB

# %%
# define features and multi-class results for modelling
non_feature = ['open', 'high', 'low', 'close', 'results',
               'shift_01', 'shift_02', 'shift_03', 'shift_05', 
               'shift_08', 'shift_13', 'shift_21', 'shift_34',
               'shift_55', 'shift_89'
               'sma_02', 'sma_03', 'sma_05', 'sma_08', 
               'sma_13', 'sma_21', 'sma_34', 'sma_55', 'sma_89',
               'diff','gain','loss']
features = [col for col in df_h1_feature.columns if col not in non_feature]

X = df_h1_feature[features]
y = df_h1_feature['results']

# %% [markdown]
# ## <font color=green>Train Test Split</font>

# %%
# shuffle=False for unrandomized time-series modelling
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, shuffle=False )

# %%
X_train.head()
# Out:
#                      hr_of_day  day_of_wk  close_shift_01_dist  \
# 2003-01-07 12:00:00         12          1                 -1.3
# 2003-01-07 13:00:00         13          1                  0.3
# 2003-01-07 14:00:00         14          1                  0.1
# 2003-01-07 15:00:00         15          1                  0.4
# 2003-01-07 16:00:00         16          1                 -0.5
#
#                      close_shift_02_dist  close_shift_03_dist  \
# 2003-01-07 12:00:00                 -2.6                 -2.5
# 2003-01-07 13:00:00                 -1.0                 -2.3
# 2003-01-07 14:00:00                  0.4                 -0.9
# 2003-01-07 15:00:00                  0.5                  0.8
# 2003-01-07 16:00:00                 -0.1                  0.0
#
#                      close_shift_05_dist  close_shift_08_dist  \
# 2003-01-07 12:00:00                 -1.9                  0.0
# 2003-01-07 13:00:00                 -0.3                  0.1
# 2003-01-07 14:00:00                 -2.1                  0.5
# 2003-01-07 15:00:00                 -1.8                 -1.1
# 2003-01-07 16:00:00                 -1.0                 -0.3
#
#                      close_shift_13_dist  close_shift_21_dist  \
# 2003-01-07 12:00:00                 -3.0                 -6.2
# 2003-01-07 13:00:00                 -2.6                 -5.2
# 2003-01-07 14:00:00                 -3.8                 -3.4
# 2003-01-07 15:00:00                 -1.8                 -2.9
# 2003-01-07 16:00:00                  0.2                 -3.2
#
#                      close_shift_34_dist  close_shift_55_dist  shift_89  \
# 2003-01-07 12:00:00                 -2.4                  1.7    1.0485
# 2003-01-07 13:00:00                 -4.6                  3.7    1.0487
# 2003-01-07 14:00:00                 -5.5                  4.3    1.0477
# 2003-01-07 15:00:00                 -6.0                  2.2    1.0470
# 2003-01-07 14:00:00      39.189721      43.222769      44.501263
# 2003-01-07 15:00:00      41.786642      41.395786      44.152998
# 2003-01-07 16:00:00      42.122482      40.639732      44.384793
#
#                      rsi_14_sma_13  rsi_14_sma_21  rsi_14_sma_03m02  \
# 2003-01-07 12:00:00      38.286167      37.541264          4.395003
# 2003-01-07 13:00:00      38.804182      37.152774          2.044855
# 2003-01-07 14:00:00      37.991146      37.395140         -1.060442
# 2003-01-07 15:00:00      38.597616      37.862777         -1.012133
# 2003-01-07 16:00:00      39.842132      38.198958         -0.692265
#
#                      rsi_14_sma_05m03  rsi_14_sma_05m02  rsi_14_sma_08m05  \
# 2003-01-07 12:00:00          0.368304          4.763308         -4.622678
# 2003-01-07 13:00:00          5.281718          7.326573         -3.170345
# 2003-01-07 14:00:00          4.033048          2.972606          1.278494
# 2003-01-07 15:00:00         -0.390855         -1.402988          2.757211
# 2003-01-07 16:00:00         -1.482750         -2.175016          3.745061
#
#                      rsi_14_sma_08m03  rsi_14_sma_08m02  rsi_14_sma_13m08  \
# 2003-01-07 12:00:00         -4.254374          0.140630         -2.663966
# 2003-01-07 13:00:00          2.111374          4.156228         -3.767653
# 2003-01-07 14:00:00          5.311542          4.251100         -6.510117
# 2003-01-07 15:00:00          2.366356          1.354223         -5.555381
# 2003-01-07 16:00:00          2.262311          1.570046         -4.542661
#
#                      rsi_14_sma_13m05  rsi_14_sma_13m03  rsi_14_sma_13m02  \
# 2003-01-07 12:00:00         -7.286644         -6.918340         -2.523337
# 2003-01-07 13:00:00         -6.937998         -1.656279          0.388575
# 2003-01-07 14:00:00         -5.231623         -1.198575         -2.259017
# 2003-01-07 15:00:00         -2.798170         -3.189026         -4.201159
# 2003-01-07 16:00:00         -0.797600         -2.280350         -2.972615
#
#                      rsi_14_sma_21m13  rsi_14_sma_21m08  rsi_14_sma_21m05  \
# 2003-01-07 12:00:00         -0.744902         -3.408869         -8.031547
# 2003-01-07 13:00:00         -1.651408         -5.419061         -8.589406
# 2003-01-07 14:00:00         -0.596007         -7.106124         -5.827630
# 2003-01-07 15:00:00         -0.734839         -6.290220         -3.533009
# 2003-01-07 16:00:00         -1.643174         -6.185835         -2.440774
#
#                      rsi_14_sma_21m03  rsi_14_sma_21m02
# 2003-01-07 12:00:00         -7.663242         -3.268239
# 2003-01-07 13:00:00         -3.307687         -1.262833
# 2003-01-07 14:00:00         -1.794582         -2.855024
# 2003-01-07 15:00:00         -3.923864         -4.935997
# 2003-01-07 16:00:00         -3.923524         -4.615789

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (79138, 161)
# (26380, 161)

# %%
y_train.value_counts(normalize=True)
# Out:
# 1    0.449102
# 2    0.434077
# 0    0.116821
# Name: results, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# 1    0.343101
# 2    0.330781
# 0    0.326118
# Name: results, dtype: float64

# %% [markdown]
# <font color=red>Due to the nature of price volatility changes and non-randomize train-test sets, the baseline accuracies for train and test sets can be rather different</font>

# %% [markdown]
# ## <font color=green>Standard Scaler</font>

# %%
ss = StandardScaler()
X_train_ss = ss.fit_transform(X_train)
X_test_ss = ss.transform(X_test)

# %% [markdown]
# ## <font color=green>Recurrent Neural Networds</font>

# %%
# reshape multi-class labels into 3 cols array
y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)

# %% [markdown]
# ## <font color=green>Training sequence = 1</font>

# %%
# Create training sequences
series_length = 1
train_sequence = TimeseriesGenerator(X_train_ss, y_train_cat, 
                                     length=series_length, 
                                     batch_size=256)

# %%
# Create test sequences
test_sequence = TimeseriesGenerator(X_test_ss, y_test_cat, 
                                    length=series_length, 
                                    batch_size=256)

# %%
# Construct RNN with L2 regularization
model = Sequential()
model.add(GRU(X_train_ss.shape[1], input_shape=(series_length,
                                                X_train_ss.shape[1]), 
                                                return_sequences=True))
model.add(GRU(X_train_ss.shape[1]))

model.add(Dense(X_train_ss.shape[1], activation='relu', 
                kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(3, activation='softmax'))

# %%
# compile neural networkds with early stopping
model.compile(optimizer=Adam(lr = .0005), 
              loss = 'categorical_crossentropy', 
              metrics=['categorical_accuracy'])

early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='auto')

# %%
history = model.fit_generator(train_sequence, 
                              validation_data=test_sequence,
                              epochs=50,
                              verbose=1,
                              callbacks=[early_stop])
# Out:
# WARNING:tensorflow:From <ipython-input-17-ec7739a5030f>:5: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 310/310 [==============================] - 4s 13ms/step - loss: 1.4740 - categorical_accuracy: 0.4453 - val_loss: 1.2505 - val_categorical_accuracy: 0.3438
# Epoch 2/50
# 310/310 [==============================] - 4s 12ms/step - loss: 0.9869 - categorical_accuracy: 0.4522 - val_loss: 1.2208 - val_categorical_accuracy: 0.3430
# Epoch 3/50
# 310/310 [==============================] - 4s 13ms/step - loss: 0.9535 - categorical_accuracy: 0.4555 - val_loss: 1.1194 - val_categorical_accuracy: 0.3416
# Epoch 4/50
# 310/310 [==============================] - 4s 14ms/step - loss: 0.9488 - categorical_accuracy: 0.4476 - val_loss: 1.1848 - val_categorical_accuracy: 0.3473
# Epoch 5/50
# 310/310 [==============================] - 5s 15ms/step - loss: 0.9422 - categorical_accuracy: 0.4605 - val_loss: 1.1713 - val_categorical_accuracy: 0.3477
# Epoch 6/50
# 310/310 [==============================] - 5s 15ms/step - loss: 0.9383 - categorical_accuracy: 0.4581 - val_loss: 1.1348 - val_categorical_accuracy: 0.3497
# Epoch 7/50
# 310/310 [==============================] - 5s 16ms/step - loss: 0.9359 - categorical_accuracy: 0.4608 - val_loss: 1.1635 - val_categorical_accuracy: 0.3459
# Epoch 8/50
# 310/310 [==============================] - 5s 16ms/step - loss: 0.9337 - categorical_accuracy: 0.4596 - val_loss: 1.1852 - val_categorical_accuracy: 0.3432
# Epoch 00008: early stopping

# %%
# plot loss curves
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='validation loss')

plt.title("Loss vs Epochs", fontsize=15)
plt.legend(fontsize=12);

# %%
# plot accuracy vs epochs
plt.plot(history.history['categorical_accuracy'], label='Train accuracy')
plt.plot(history.history['val_categorical_accuracy'], label='Val accuracy')
plt.legend();

# %%
rnn_pred = np.argmax(model.predict(test_sequence), axis=-1)
cm = confusion_matrix(y_test[series_length:], rnn_pred)
cm_df = pd.DataFrame(cm, columns=['pred 0', 'pred 1', 'pred 2'], index=['actual 0', 'actual 1', 'actual 2'])
cm_df
# Out:
#           pred 0  pred 1  pred 2
# actual 0       0    7978     625
# actual 1       0    7964    1087
# actual 2       0    7636    1089

# %%
cm_df.loc['actual 1'][1]/(cm_df['pred 1'].sum())
# Out:
# 0.3377724997879379

# %%
cm_df.loc['actual 2'][2]/(cm_df['pred 2'].sum())
# Out:
# 0.3887897179578722

# %%
(cm_df.loc['actual 1'][1]+cm_df.loc['actual 2'][2])/((cm_df['pred 1'].sum())+(cm_df['pred 2'].sum()))
# Out:
# 0.3431896584404261

# %%
rnn_proba = model.predict_proba(test_sequence)
# Out:
# WARNING:tensorflow:From <ipython-input-24-17c6cf80d2b9>:1: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.

# %%
rnn_proba = pd.DataFrame(rnn_proba)
rnn_proba.head()
# Out:
#           0         1         2
# 0  0.096910  0.462587  0.440502
# 1  0.108876  0.454359  0.436765
# 2  0.137726  0.441471  0.420803
# 3  0.118685  0.449396  0.431918
# 4  0.114720  0.451290  0.433990

# %%
results_compare = pd.DataFrame(X_test["hr_of_day"][series_length:])
results_compare['results'] = pd.DataFrame(y_test[series_length:])
results_compare['pred'] = rnn_pred
results_compare['compare'] = (results_compare['results'] == results_compare['pred']).astype(int)
results_compare['proba_0'] = rnn_proba[0].values
results_compare['proba_1'] = rnn_proba[1].values
results_compare['proba_2'] = rnn_proba[2].values

# %%
results_compare.head()
# Out:
#                      hr_of_day  results  pred  compare   proba_0   proba_1  \
# 2015-10-01 17:00:00         17        1     1        1  0.096910  0.462587
# 2015-10-01 18:00:00         18        1     1        1  0.108876  0.454359
# 2015-10-01 19:00:00         19        1     1        1  0.137726  0.441471
# 2015-10-01 20:00:00         20        1     1        1  0.118685  0.449396
# 2015-10-01 21:00:00         21        2     1        0  0.114720  0.451290
#
#                       proba_2
# 2015-10-01 17:00:00  0.440502
# 2015-10-01 18:00:00  0.436765
# 2015-10-01 19:00:00  0.420803
# 2015-10-01 20:00:00  0.431918
# 2015-10-01 21:00:00  0.433990

# %%
pred_1 = results_compare[results_compare['pred']==1]
pred_1.head()
# Out:
#                      hr_of_day  results  pred  compare   proba_0   proba_1  \
# 2015-10-01 17:00:00         17        1     1        1  0.096910  0.462587
# 2015-10-01 18:00:00         18        1     1        1  0.108876  0.454359
# 2015-10-01 19:00:00         19        1     1        1  0.137726  0.441471
# 2015-10-01 20:00:00         20        1     1        1  0.118685  0.449396
# 2015-10-01 21:00:00         21        2     1        0  0.114720  0.451290
#
#                       proba_2
# 2015-10-01 17:00:00  0.440502
# 2015-10-01 18:00:00  0.436765
# 2015-10-01 19:00:00  0.420803
# 2015-10-01 20:00:00  0.431918
# 2015-10-01 21:00:00  0.433990

# %%
plt.hist(pred_1[pred_1['compare']==1]['proba_1'], label="1", bins=20)
plt.hist(pred_1[pred_1['compare']==0]['proba_1'], alpha = 0.5, label="0", bins=20);

# %%
pred_2 = results_compare[results_compare['pred']==2]
pred_2.head()
# Out:
#                      hr_of_day  results  pred  compare   proba_0   proba_1  \
# 2015-10-02 04:00:00          4        1     2        0  0.118920  0.440388
# 2015-10-02 05:00:00          5        1     2        0  0.137715  0.428959
# 2015-10-02 06:00:00          6        1     2        0  0.173867  0.408668
# 2015-10-02 07:00:00          7        1     2        0  0.224461  0.387053
# 2015-10-02 08:00:00          8        2     2        1  0.222282  0.388412
#
#                       proba_2
# 2015-10-02 04:00:00  0.440691
# 2015-10-02 05:00:00  0.433327
# 2015-10-02 06:00:00  0.417465
# 2015-10-02 07:00:00  0.388485
# 2015-10-02 08:00:00  0.389306

# %%
plt.hist(pred_2[pred_2['compare']==1]['proba_2'], label="1", bins =20)
plt.hist(pred_2[pred_2['compare']==0]['proba_2'], alpha = 0.5, label='0', bins =20);

plt.legend()

# %% [markdown]
# ## <font color=green>Training sequence = 3</font>

# %%
# Create training sequences
series_length = 3
train_sequence = TimeseriesGenerator(X_train_ss, y_train_cat, 
                                     length=series_length, 
                                     batch_size=256)

# %%
# Create test sequences
test_sequence = TimeseriesGenerator(X_test_ss, y_test_cat, 
                                    length=series_length, 
                                    batch_size=256)

# %%
# Construct RNN with L2 regularization
model = Sequential()
model.add(GRU(X_train_ss.shape[1], input_shape=(series_length,
                                                X_train_ss.shape[1]), 
                                                return_sequences=True))
model.add(GRU(X_train_ss.shape[1]))

model.add(Dense(X_train_ss.shape[1], activation='relu', 
                kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(3, activation='softmax'))

# %%
# compile neural networkds with early stopping
model.compile(optimizer=Adam(lr = .0005), 
              loss = 'categorical_crossentropy', 
              metrics=['categorical_accuracy'])

early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='auto')

# %%
history = model.fit_generator(train_sequence, 
                              validation_data=test_sequence,
                              epochs=50,
                              verbose=1,
                              callbacks=[early_stop])
# Out:
# Epoch 1/50
# 310/310 [==============================] - 12s 38ms/step - loss: 1.5861 - categorical_accuracy: 0.4434 - val_loss: 1.3671 - val_categorical_accuracy: 0.3388
# Epoch 2/50
# 310/310 [==============================] - 12s 38ms/step - loss: 1.0164 - categorical_accuracy: 0.4534 - val_loss: 1.2100 - val_categorical_accuracy: 0.3409
# Epoch 3/50
# 310/310 [==============================] - 12s 40ms/step - loss: 0.9613 - categorical_accuracy: 0.4457 - val_loss: 1.1552 - val_categorical_accuracy: 0.3481
# Epoch 4/50
# 310/310 [==============================] - 13s 40ms/step - loss: 0.9463 - categorical_accuracy: 0.4547 - val_loss: 1.2045 - val_categorical_accuracy: 0.3527
# Epoch 5/50
# 310/310 [==============================] - 13s 41ms/step - loss: 0.9407 - categorical_accuracy: 0.4570 - val_loss: 1.1509 - val_categorical_accuracy: 0.3488
# Epoch 6/50
# 310/310 [==============================] - 13s 41ms/step - loss: 0.9377 - categorical_accuracy: 0.4596 - val_loss: 1.1446 - val_categorical_accuracy: 0.3499
# Epoch 7/50
# 310/310 [==============================] - 13s 41ms/step - loss: 0.9314 - categorical_accuracy: 0.4650 - val_loss: 1.1802 - val_categorical_accuracy: 0.3538
# Epoch 8/50
# 310/310 [==============================] - 13s 42ms/step - loss: 0.9286 - categorical_accuracy: 0.4692 - val_loss: 1.1884 - val_categorical_accuracy: 0.3519
# Epoch 9/50
# 310/310 [==============================] - 13s 42ms/step - loss: 0.9238 - categorical_accuracy: 0.4677 - val_loss: 1.2771 - val_categorical_accuracy: 0.3461
# Epoch 10/50
# 310/310 [==============================] - 13s 42ms/step - loss: 0.9216 - categorical_accuracy: 0.4738 - val_loss: 1.3515 - val_categorical_accuracy: 0.3499
# Epoch 11/50
# 310/310 [==============================] - 13s 42ms/step - loss: 0.9194 - categorical_accuracy: 0.4784 - val_loss: 1.2398 - val_categorical_accuracy: 0.3459
# Epoch 00011: early stopping

# %%
# plot loss curves
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='validation loss')

plt.title("Loss vs Epochs", fontsize=15)
plt.legend(fontsize=12);

# %%
# plot accuracy vs epochs
plt.plot(history.history['categorical_accuracy'], label='Train accuracy')
plt.plot(history.history['val_categorical_accuracy'], label='Val accuracy')
plt.legend();

# %%
rnn_pred = np.argmax(model.predict(test_sequence), axis=-1)
cm = confusion_matrix(y_test[series_length:], rnn_pred)
cm_df = pd.DataFrame(cm, columns=['pred 0', 'pred 1', 'pred 2'], index=['actual 0', 'actual 1', 'actual 2'])
cm_df
# Out:
#           pred 0  pred 1  pred 2
# actual 0       0    5372    3231
# actual 1       0    5003    4046
# actual 2       2    4603    4120

# %%
cm_df.loc['actual 1'][1]/(cm_df['pred 1'].sum())
# Out:
# 0.33402323407664575

# %%
cm_df.loc['actual 2'][2]/(cm_df['pred 2'].sum())
# Out:
# 0.3614986399929806

# %%
(cm_df.loc['actual 1'][1]+cm_df.loc['actual 2'][2])/((cm_df['pred 1'].sum())+(cm_df['pred 2'].sum()))
# Out:
# 0.3458957345971564

# %%
rnn_proba = model.predict_proba(test_sequence)

# %%
rnn_proba = pd.DataFrame(rnn_proba)
rnn_proba.head()
# Out:
#           0         1         2
# 0  0.108376  0.418034  0.473590
# 1  0.105369  0.422324  0.472307
# 2  0.103625  0.427597  0.468778
# 3  0.097202  0.428605  0.474193
# 4  0.091209  0.432289  0.476502

# %%
results_compare = pd.DataFrame(X_test["hr_of_day"][series_length:])
results_compare['results'] = pd.DataFrame(y_test[series_length:])
results_compare['pred'] = rnn_pred
results_compare['compare'] = (results_compare['results'] == results_compare['pred']).astype(int)
results_compare['proba_0'] = rnn_proba[0].values
results_compare['proba_1'] = rnn_proba[1].values
results_compare['proba_2'] = rnn_proba[2].values

# %%
results_compare.head()
# Out:
#                      hr_of_day  results  pred  compare   proba_0   proba_1  \
# 2015-10-01 19:00:00         19        1     2        0  0.108376  0.418034
# 2015-10-01 20:00:00         20        1     2        0  0.105369  0.422324
# 2015-10-01 21:00:00         21        2     2        1  0.103625  0.427597
# 2015-10-01 22:00:00         22        1     2        0  0.097202  0.428605
# 2015-10-01 23:00:00         23        1     2        0  0.091209  0.432289
#
#                       proba_2
# 2015-10-01 19:00:00  0.473590
# 2015-10-01 20:00:00  0.472307
# 2015-10-01 21:00:00  0.468778
# 2015-10-01 22:00:00  0.474193
# 2015-10-01 23:00:00  0.476502

# %%
pred_1 = results_compare[results_compare['pred']==1]
pred_1.head()
# Out:
#                      hr_of_day  results  pred  compare   proba_0   proba_1  \
# 2015-10-02 10:00:00         10        2     1        0  0.212912  0.419639
# 2015-10-02 11:00:00         11        2     1        0  0.259297  0.419480
# 2015-10-02 12:00:00         12        1     1        1  0.265630  0.410458
# 2015-10-02 13:00:00         13        1     1        1  0.181674  0.456339
# 2015-10-02 14:00:00         14        1     1        1  0.087954  0.506573
#
#                       proba_2
# 2015-10-02 10:00:00  0.367449
# 2015-10-02 11:00:00  0.321223
# 2015-10-02 12:00:00  0.323912
# 2015-10-02 13:00:00  0.361988
# 2015-10-02 14:00:00  0.405472

# %%
plt.hist(pred_1[pred_1['compare']==1]['proba_1'], label="1", bins=20)
plt.hist(pred_1[pred_1['compare']==0]['proba_1'], alpha = 0.5, label="0", bins=20);

# %%
pred_2 = results_compare[results_compare['pred']==2]
pred_2.head()
# Out:
#                      hr_of_day  results  pred  compare   proba_0   proba_1  \
# 2015-10-01 19:00:00         19        1     2        0  0.108376  0.418034
# 2015-10-01 20:00:00         20        1     2        0  0.105369  0.422324
# 2015-10-01 21:00:00         21        2     2        1  0.103625  0.427597
# 2015-10-01 22:00:00         22        1     2        0  0.097202  0.428605
# 2015-10-01 23:00:00         23        1     2        0  0.091209  0.432289
#
#                       proba_2
# 2015-10-01 19:00:00  0.473590
# 2015-10-01 20:00:00  0.472307
# 2015-10-01 21:00:00  0.468778
# 2015-10-01 22:00:00  0.474193
# 2015-10-01 23:00:00  0.476502

# %%
plt.hist(pred_2[pred_2['compare']==1]['proba_2'], label="1", bins =20)
plt.hist(pred_2[pred_2['compare']==0]['proba_2'], alpha = 0.5, label='0', bins =20);

plt.legend()

# %% [markdown]
# ## <font color=green>Training sequence = 5</font>

# %%
# Create training sequences
series_length = 5
train_sequence = TimeseriesGenerator(X_train_ss, y_train_cat, 
                                     length=series_length, 
                                     batch_size=256)

# %%
# Create test sequences
test_sequence = TimeseriesGenerator(X_test_ss, y_test_cat, 
                                    length=series_length, 
                                    batch_size=256)

# %%
# Construct RNN with L2 regularization
model = Sequential()
model.add(GRU(X_train_ss.shape[1], input_shape=(series_length,
                                                X_train_ss.shape[1]), 
                                                return_sequences=True))
model.add(GRU(X_train_ss.shape[1]))

model.add(Dense(X_train_ss.shape[1], activation='relu', 
                kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(3, activation='softmax'))

# %%
# compile neural networkds with early stopping
model.compile(optimizer=Adam(lr = .0005), 
              loss = 'categorical_crossentropy', 
              metrics=['categorical_accuracy'])

early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='auto')

# %%
history = model.fit_generator(train_sequence, 
                              validation_data=test_sequence,
                              epochs=50,
                              verbose=1,
                              callbacks=[early_stop])
# Out:
# Epoch 1/50
# 310/310 [==============================] - 22s 70ms/step - loss: 1.6314 - categorical_accuracy: 0.4505 - val_loss: 1.3695 - val_categorical_accuracy: 0.3496
# Epoch 2/50
# 310/310 [==============================] - 21s 68ms/step - loss: 1.0423 - categorical_accuracy: 0.4530 - val_loss: 1.2462 - val_categorical_accuracy: 0.3473
# Epoch 3/50
# 310/310 [==============================] - 21s 68ms/step - loss: 0.9687 - categorical_accuracy: 0.4597 - val_loss: 1.2277 - val_categorical_accuracy: 0.3384
# Epoch 4/50
# 310/310 [==============================] - 21s 68ms/step - loss: 0.9506 - categorical_accuracy: 0.4503 - val_loss: 1.1961 - val_categorical_accuracy: 0.3485
# Epoch 5/50
# 310/310 [==============================] - 21s 68ms/step - loss: 0.9409 - categorical_accuracy: 0.4584 - val_loss: 1.3018 - val_categorical_accuracy: 0.3496
# Epoch 6/50
# 310/310 [==============================] - 21s 67ms/step - loss: 0.9397 - categorical_accuracy: 0.4579 - val_loss: 1.2904 - val_categorical_accuracy: 0.3454
# Epoch 7/50
# 310/310 [==============================] - 21s 67ms/step - loss: 0.9312 - categorical_accuracy: 0.4591 - val_loss: 1.1992 - val_categorical_accuracy: 0.3423
# Epoch 8/50
# 310/310 [==============================] - 21s 67ms/step - loss: 0.9281 - categorical_accuracy: 0.4694 - val_loss: 1.3799 - val_categorical_accuracy: 0.3444
# Epoch 9/50
# 310/310 [==============================] - 21s 68ms/step - loss: 0.9244 - categorical_accuracy: 0.4719 - val_loss: 1.2030 - val_categorical_accuracy: 0.3529
# Epoch 00009: early stopping

# %%
# plot loss curves
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='validation loss')

plt.title("Loss vs Epochs", fontsize=15)
plt.legend(fontsize=12);

# %%
# plot accuracy vs epochs
plt.plot(history.history['categorical_accuracy'], label='Train accuracy')
plt.plot(history.history['val_categorical_accuracy'], label='Val accuracy')
plt.legend();

# %%
rnn_pred = np.argmax(model.predict(test_sequence), axis=-1)
cm = confusion_matrix(y_test[series_length:], rnn_pred)
cm_df = pd.DataFrame(cm, columns=['pred 0', 'pred 1', 'pred 2'], index=['actual 0', 'actual 1', 'actual 2'])
cm_df
# Out:
#           pred 0  pred 1  pred 2
# actual 0     322    6665    1616
# actual 1     210    6570    2267
# actual 2     217    6093    2415

# %%
cm_df.loc['actual 1'][1]/(cm_df['pred 1'].sum())
# Out:
# 0.33992135761589404

# %%
cm_df.loc['actual 2'][2]/(cm_df['pred 2'].sum())
# Out:
# 0.38345506510003174

# %%
(cm_df.loc['actual 1'][1]+cm_df.loc['actual 2'][2])/((cm_df['pred 1'].sum())+(cm_df['pred 2'].sum()))
# Out:
# 0.3506204635916647

# %%
rnn_proba = model.predict_proba(test_sequence)

# %%
rnn_proba = pd.DataFrame(rnn_proba)
rnn_proba.head()
# Out:
#           0         1         2
# 0  0.096769  0.433515  0.469716
# 1  0.098049  0.435786  0.466165
# 2  0.115764  0.426987  0.457249
# 3  0.102815  0.429963  0.467222
# 4  0.096545  0.431341  0.472115

# %%
results_compare = pd.DataFrame(X_test["hr_of_day"][series_length:])
results_compare['results'] = pd.DataFrame(y_test[series_length:])
results_compare['pred'] = rnn_pred
results_compare['compare'] = (results_compare['results'] == results_compare['pred']).astype(int)
results_compare['proba_0'] = rnn_proba[0].values
results_compare['proba_1'] = rnn_proba[1].values
results_compare['proba_2'] = rnn_proba[2].values

# %%
results_compare.head()
# Out:
#                      hr_of_day  results  pred  compare   proba_0   proba_1  \
# 2015-10-01 21:00:00         21        2     2        1  0.096769  0.433515
# 2015-10-01 22:00:00         22        1     2        0  0.098049  0.435786
# 2015-10-01 23:00:00         23        1     2        0  0.115764  0.426987
# 2015-10-02 00:00:00          0        1     2        0  0.102815  0.429963
# 2015-10-02 01:00:00          1        1     2        0  0.096545  0.431341
#
#                       proba_2
# 2015-10-01 21:00:00  0.469716
# 2015-10-01 22:00:00  0.466165
# 2015-10-01 23:00:00  0.457249
# 2015-10-02 00:00:00  0.467222
# 2015-10-02 01:00:00  0.472115

# %%
pred_1 = results_compare[results_compare['pred']==1]
pred_1.head()
# Out:
#                      hr_of_day  results  pred  compare   proba_0   proba_1  \
# 2015-10-02 09:00:00          9        2     1        0  0.160915  0.449481
# 2015-10-02 10:00:00         10        2     1        0  0.202886  0.434578
# 2015-10-02 11:00:00         11        2     1        0  0.223253  0.429020
# 2015-10-02 12:00:00         12        1     1        1  0.210317  0.440579
# 2015-10-02 13:00:00         13        1     1        1  0.144377  0.480043
#
#                       proba_2
# 2015-10-02 09:00:00  0.389604
# 2015-10-02 10:00:00  0.362536
# 2015-10-02 11:00:00  0.347728
# 2015-10-02 12:00:00  0.349103
# 2015-10-02 13:00:00  0.375581

# %%
plt.hist(pred_1[pred_1['compare']==1]['proba_1'], label="1", bins=20)
plt.hist(pred_1[pred_1['compare']==0]['proba_1'], alpha = 0.5, label="0", bins=20);

# %%
pred_2 = results_compare[results_compare['pred']==2]
pred_2.head()
# Out:
#                      hr_of_day  results  pred  compare   proba_0   proba_1  \
# 2015-10-01 21:00:00         21        2     2        1  0.096769  0.433515
# 2015-10-01 22:00:00         22        1     2        0  0.098049  0.435786
# 2015-10-01 23:00:00         23        1     2        0  0.115764  0.426987
# 2015-10-02 00:00:00          0        1     2        0  0.102815  0.429963
# 2015-10-02 01:00:00          1        1     2        0  0.096545  0.431341
#
#                       proba_2
# 2015-10-01 21:00:00  0.469716
# 2015-10-01 22:00:00  0.466165
# 2015-10-01 23:00:00  0.457249
# 2015-10-02 00:00:00  0.467222
# 2015-10-02 01:00:00  0.472115

# %%
plt.hist(pred_2[pred_2['compare']==1]['proba_2'], label="1", bins =20)
plt.hist(pred_2[pred_2['compare']==0]['proba_2'], alpha = 0.5, label='0', bins =20);

plt.legend()

# %% [markdown]
# ## <font color=green>Training sequence = 7</font>

# %%
# Create training sequences
series_length = 7
train_sequence = TimeseriesGenerator(X_train_ss, y_train_cat, 
                                     length=series_length, 
                                     batch_size=256)

# %%
# Create test sequences
test_sequence = TimeseriesGenerator(X_test_ss, y_test_cat, 
                                    length=series_length, 
                                    batch_size=256)

# %%
# Construct RNN with L2 regularization
model = Sequential()
model.add(GRU(X_train_ss.shape[1], input_shape=(series_length,
                                                X_train_ss.shape[1]), 
                                                return_sequences=True))
model.add(GRU(X_train_ss.shape[1]))

model.add(Dense(X_train_ss.shape[1], activation='relu', 
                kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(3, activation='softmax'))

# %%
# compile neural networkds with early stopping
model.compile(optimizer=Adam(lr = .0005), 
              loss = 'categorical_crossentropy', 
              metrics=['categorical_accuracy'])

early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='auto')

# %%
history = model.fit_generator(train_sequence, 
                              validation_data=test_sequence,
                              epochs=50,
                              verbose=1,
                              callbacks=[early_stop])
# Out:
# Epoch 1/50
# 310/310 [==============================] - 28s 90ms/step - loss: 1.6662 - categorical_accuracy: 0.4438 - val_loss: 1.4012 - val_categorical_accuracy: 0.3502
# Epoch 2/50
# 310/310 [==============================] - 26s 85ms/step - loss: 1.0599 - categorical_accuracy: 0.4590 - val_loss: 1.2797 - val_categorical_accuracy: 0.3476
# Epoch 3/50
# 310/310 [==============================] - 26s 85ms/step - loss: 0.9735 - categorical_accuracy: 0.4556 - val_loss: 1.2030 - val_categorical_accuracy: 0.3490
# Epoch 4/50
# 310/310 [==============================] - 26s 85ms/step - loss: 0.9512 - categorical_accuracy: 0.4588 - val_loss: 1.2851 - val_categorical_accuracy: 0.3432
# Epoch 5/50
# 310/310 [==============================] - 27s 87ms/step - loss: 0.9427 - categorical_accuracy: 0.4559 - val_loss: 1.2496 - val_categorical_accuracy: 0.3432
# Epoch 6/50
# 310/310 [==============================] - 28s 92ms/step - loss: 0.9325 - categorical_accuracy: 0.4649 - val_loss: 1.2114 - val_categorical_accuracy: 0.3511
# Epoch 7/50
# 310/310 [==============================] - 28s 90ms/step - loss: 0.9295 - categorical_accuracy: 0.4682 - val_loss: 1.2643 - val_categorical_accuracy: 0.3433
# Epoch 8/50
# 310/310 [==============================] - 27s 89ms/step - loss: 0.9259 - categorical_accuracy: 0.4640 - val_loss: 1.3440 - val_categorical_accuracy: 0.3443
# Epoch 00008: early stopping

# %%
# plot loss curves
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='validation loss')

plt.title("Loss vs Epochs", fontsize=15)
plt.legend(fontsize=12);

# %%
# plot accuracy vs epochs
plt.plot(history.history['categorical_accuracy'], label='Train accuracy')
plt.plot(history.history['val_categorical_accuracy'], label='Val accuracy')
plt.legend();

# %%
rnn_pred = np.argmax(model.predict(test_sequence), axis=-1)
cm = confusion_matrix(y_test[series_length:], rnn_pred)
cm_df = pd.DataFrame(cm, columns=['pred 0', 'pred 1', 'pred 2'], index=['actual 0', 'actual 1', 'actual 2'])
cm_df
# Out:
#           pred 0  pred 1  pred 2
# actual 0       0    7961     642
# actual 1       0    8004    1042
# actual 2       0    7649    1075

# %%
cm_df.loc['actual 1'][1]/(cm_df['pred 1'].sum())
# Out:
# 0.3389514694672652

# %%
cm_df.loc['actual 2'][2]/(cm_df['pred 2'].sum())
# Out:
# 0.3896339253352664

# %%
(cm_df.loc['actual 1'][1]+cm_df.loc['actual 2'][2])/((cm_df['pred 1'].sum())+(cm_df['pred 2'].sum()))
# Out:
# 0.344253592689493

# %%
rnn_proba = model.predict_proba(test_sequence)

# %%
rnn_proba = pd.DataFrame(rnn_proba)
rnn_proba.head()
# Out:
#           0         1         2
# 0  0.050029  0.497457  0.452514
# 1  0.044152  0.497558  0.458290
# 2  0.042704  0.494906  0.462390
# 3  0.038804  0.495082  0.466114
# 4  0.037071  0.493703  0.469226

# %%
results_compare = pd.DataFrame(X_test["hr_of_day"][series_length:])
results_compare['results'] = pd.DataFrame(y_test[series_length:])
results_compare['pred'] = rnn_pred
results_compare['compare'] = (results_compare['results'] == results_compare['pred']).astype(int)
results_compare['proba_0'] = rnn_proba[0].values
results_compare['proba_1'] = rnn_proba[1].values
results_compare['proba_2'] = rnn_proba[2].values

# %%
results_compare.head()
# Out:
#                      hr_of_day  results  pred  compare   proba_0   proba_1  \
# 2015-10-01 23:00:00         23        1     1        1  0.050029  0.497457
# 2015-10-02 00:00:00          0        1     1        1  0.044152  0.497558
# 2015-10-02 01:00:00          1        1     1        1  0.042704  0.494906
# 2015-10-02 02:00:00          2        1     1        1  0.038804  0.495082
# 2015-10-02 03:00:00          3        1     1        1  0.037071  0.493703
#
#                       proba_2
# 2015-10-01 23:00:00  0.452514
# 2015-10-02 00:00:00  0.458290
# 2015-10-02 01:00:00  0.462390
# 2015-10-02 02:00:00  0.466114
# 2015-10-02 03:00:00  0.469226

# %%
pred_1 = results_compare[results_compare['pred']==1]
pred_1.head()
# Out:
#                      hr_of_day  results  pred  compare   proba_0   proba_1  \
# 2015-10-01 23:00:00         23        1     1        1  0.050029  0.497457
# 2015-10-02 00:00:00          0        1     1        1  0.044152  0.497558
# 2015-10-02 01:00:00          1        1     1        1  0.042704  0.494906
# 2015-10-02 02:00:00          2        1     1        1  0.038804  0.495082
# 2015-10-02 03:00:00          3        1     1        1  0.037071  0.493703
#
#                       proba_2
# 2015-10-01 23:00:00  0.452514
# 2015-10-02 00:00:00  0.458290
# 2015-10-02 01:00:00  0.462390
# 2015-10-02 02:00:00  0.466114
# 2015-10-02 03:00:00  0.469226

# %%
plt.hist(pred_1[pred_1['compare']==1]['proba_1'], label="1", bins=20)
plt.hist(pred_1[pred_1['compare']==0]['proba_1'], alpha = 0.5, label="0", bins=20);

# %%
pred_2 = results_compare[results_compare['pred']==2]
pred_2.head()
# Out:
#                      hr_of_day  results  pred  compare   proba_0   proba_1  \
# 2015-10-02 08:00:00          8        2     2        1  0.093219  0.450300
# 2015-10-06 22:00:00         22        2     2        1  0.076260  0.461160
# 2015-10-06 23:00:00         23        2     2        1  0.075891  0.460517
# 2015-10-07 00:00:00          0        2     2        1  0.072607  0.461073
# 2015-10-07 01:00:00          1        2     2        1  0.063728  0.465918
#
#                       proba_2
# 2015-10-02 08:00:00  0.456481
# 2015-10-06 22:00:00  0.462580
# 2015-10-06 23:00:00  0.463592
# 2015-10-07 00:00:00  0.466320
# 2015-10-07 01:00:00  0.470355

# %%
plt.hist(pred_2[pred_2['compare']==1]['proba_2'], label="1", bins =20)
plt.hist(pred_2[pred_2['compare']==0]['proba_2'], alpha = 0.5, label='0', bins =20);

plt.legend()
